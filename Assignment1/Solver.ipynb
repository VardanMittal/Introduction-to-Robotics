# %%
import numpy as np
from Tasks.main import trajectory, plot_traj

# %% [markdown]
# ##  trajectories

# %%
t = np.linspace(1,10,100)

# %% [markdown]
# 1. ellipse

# %%
a = 4
b = 3
x = a * np.cos(t)
y = b * np.sin(t)

# %%
ee_traj = trajectory(x,y)

# %%
plot_traj(x,y,ee_traj)

# %% [markdown]
# 2. Spiral

# %%
x_spiral = t * np.sin(t) / 2
y_spiral = t  * np.cos(t) / 2

# %%
ee_spiral = trajectory(x_spiral,y_spiral)
plot_traj(x_spiral,y_spiral,ee_spiral)

# %% [markdown]
# 3. Cy

# %%
t = np.linspace(-1,1,100)

# %%
x_cy = b * np.tan(t)
y_cy = a * (1 / np.cos(t))

# %%
ee_cy = trajectory(x_cy,y_cy)

# %%
plot_traj(x_cy,y_cy,ee_cy)
